# %% [markdown]
# Task 1:
#
# Read the CSV file in Pandas and create a DataFrame named Grc_df.
# What is the number of rows and columns in Grc_df?
# Print the first 10 and last 10 rows of Grc_df

# %%
# Her er de nødvendige importene for oppgavene
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# deloppgave 1, del 1/2: 
# What is the number of rows and columns in Grc_df?

# Steg 1: Leser CSV filen inn i Pandas DataFrame
Grc_df = pd.read_csv('Grocery_dataset.csv')

# Steg 2: Finner antall rader og kollonner i filen
num_rows, num_columns = Grc_df.shape

print(f"The numnber of row is: {num_rows}")
print(f"The number of columns is: {num_columns}")
# Out:
# The numnber of row is: 5000
# The number of columns is: 12

# %%
# deloppgave 1, del 2/2:
# Print the first 10 and last 10 rows of Grc_df

print("\nFirst 10 rows of Grc_df:")
Grc_df.head(10)
# Out:
# First 10 rows of Grc_df:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
print("\nLast 10 rows og Grc_df:")
Grc_df.tail(10)
# Out:
# Last 10 rows og Grc_df:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4990           FDE46        18.60          Low Fat         0.015859
# 4991           NCQ53        17.60          Low Fat         0.018905
# 4992           NCN42        20.25          Low Fat         0.014281
# 4993           DRH11         5.98          Low Fat         0.075675
# 4994           NCI42        18.75          Low Fat         0.010382
# 4995           FDT07         5.82          Regular         0.077476
# 4996           DRL60         8.52          Low Fat         0.027059
# 4997           FDG20        15.50          Regular         0.126200
# 4998           FDF56        16.70          Regular         0.119462
# 4999           FDV33         9.60          Regular         0.027455
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4990            Snack Foods  152.9366            OUT017
# 4991     Health and Hygiene  234.6590            OUT046
# ...

# %% [markdown]
# Task 2:
#
# Are there any null values in the Grc_df? If yes, then in which columns and how many? Finally, handle these null values using any strategy shown during the labs.

# %%
# Sjekker for null verdier i hver kolonne
null_counts = Grc_df.isnull().sum()

print("Number of null values in each column:")
print(null_counts)
# Out:
# Number of null values in each column:
# Item_Identifier                 0
# Item_Weight                   818
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1439
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Svar: Ja, det er null verdier i Grc_df DataFrame. De er blitt funnet i følgene kolonner:
#
# Item_Weight: har 1463 null verdier,
# Outlet_Size: har 2410 null verdier

# %%
# Strategien vi bruker her er å flatfylle verdiene med gjennomsnittet
# Håndterer null verdiene for 'Item_Weight' ved å fylle inn gjennomsnittet
mean_Weight = Grc_df['Item_Weight'].mean()
Grc_df['Item_Weight'].fillna(mean_Weight, inplace=True)

# Håndterer null verdier for 'Outlet_Size' ved å fyllle ut med den som er mest brukt
mode_size = Grc_df['Outlet_Size'].mode()[0]
Grc_df['Outlet_Size'].fillna(mode_size, inplace=True)

# Verifiserer om null verdiene har blitt behandlet
print("\nNumber of null values after handling:")
print(Grc_df.isnull().sum())
# Out:
# Number of null values after handling:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7668\246295955.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# Task 3:
#
# How many unique Outlet Sizes are there in the Grc_df?
# Which outlet size is maximum, and which is minimum?

# %%
# Deloppgave 3, del 1/2:
# How many unique Outlet Sizes are there in the Grc_df? 

# Hent antallene for hver unike verdi i kolonnen 'Outlet_Size'
outlet_size_counts = Grc_df['Outlet_Size'].value_counts()
# print(f"{outlet_size_counts}") # debug print
num_unique_sizes = len(outlet_size_counts)

print(f"There are {num_unique_sizes} unique Outlet Sizes in the DataFrame.")
print("\nHere are the counts for each size:")
print(outlet_size_counts)
# Out:
# There are 3 unique Outlet Sizes in the DataFrame.
#
# Here are the counts for each size:
# Outlet_Size
# Medium    3044
# Small     1398
# High       558
# Name: count, dtype: int64

# %%
# Deloppgave 3, del 2/2:
# How many unique Outlet Sizes are there in the Grc_df? 

# Maksimum er den første indeksen i value_counts-serien
max_size = outlet_size_counts.index[0]

# Minimumet er den siste indeksen i value_counts-serien
min_size = outlet_size_counts.index[-1]

print(f"\nThe outlet size with the maximum number of outlets is: '{max_size}'")
print(f"The outlet size with the minimum number of outlets is: '{min_size}'")
# Out:
# The outlet size with the maximum number of outlets is: 'Medium'
# The outlet size with the minimum number of outlets is: 'High'

# %% [markdown]
# Task 4:
#
# How many unique Item Fat Content types are in the Grc_df? List them. Do you see any issues with the Item Fat Content types?
# If yes, then handle this issue.

# %%
# Oppgave 4: del 1/2 
# How many unique Item Fat Content types are in the Grc_df?

# Henter de unike verdiene og antallene deres for 'Item_Fat_Content'
fat_content_counts = Grc_df['Item_Fat_Content'].value_counts()

print(f"There are {len(fat_content_counts)} unique 'Item Fat Content' types.")
print("\nHere is a list of the types and their counts:")
print(fat_content_counts)
# Out:
# There are 5 unique 'Item Fat Content' types.
#
# Here is a list of the types and their counts:
# Item_Fat_Content
# Low Fat    3008
# Regular    1679
# LF          183
# reg          68
# low fat      62
# Name: count, dtype: int64

# %%
# Oppgave 4: del 2/2
# Do you see any issues with the Item Fat Content types? 

# Steg 1: Definerer en "ordbok" for erstatningene
replacements = {
    'low fat': 'Low Fat',
    'LF': 'Low Fat',
    'reg': 'Regular'
}

# Steg 2: Bruker .replace() for å utføre endringer i kolonnen
Grc_df['Item_Fat_Content'] = Grc_df['Item_Fat_Content'].replace(replacements)


# Steg 3: Verifiser at problemet er løst ved å kjøre value_counts() på nytt
print("\n'Item Fat Content'-typer etter opprydding:")
print(Grc_df['Item_Fat_Content'].value_counts())
# Out:
# 'Item Fat Content'-typer etter opprydding:
# Item_Fat_Content
# Low Fat    3253
# Regular    1747
# Name: count, dtype: int64

# %% [markdown]
# Task 5:
#
# Drop the columns having index values of 0, 6 and create a new DataFrame Grc_new_df.

# %%
# Printer ut kolonnene før og etter for sammenligning
print("Columns in the old DataFrame:")
print(Grc_df.columns)

# henter navnene til colonnene på index 0 og 6
columns_to_drop = Grc_df.columns[[0,6]]

# Dropper disse kolonnene og lager en ny Dataframe
Grc_new_df = Grc_df.drop(columns=columns_to_drop)
# debug log som viser at vi har kommet et hakk videre i prosessen
print("\nColumns dropped successfully. New DataFrame 'Grc_new_df' created.")

# printer de første 5 radene for å verifisere resultatet
# man kan se at Item_identifier og Outlet_Identifier er fjernet nå
print("\nFirst 5 rows of the new Grc_new_df:")
display(Grc_new_df.head())

# printer listen av kolonnene for den nye tabellen Grc_new_df
print("\nColumns in the new DataFrame:")
print(Grc_new_df.columns)
# Out:
# Columns in the old DataFrame:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')
#
# Columns dropped successfully. New DataFrame 'Grc_new_df' created.
#
# First 5 rows of the new Grc_new_df:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %% [markdown]
# Task 6:
#
# Using different Supermarket type listed in the column Outlet_Type create two different DataFrames from Grc_new_df. Name these DataFrames as SupType_1 and SupType_2.

# %%
# Starter med å se hvilke unike verdier 'Outlet_Type' kolonnen inneholder
print("Unique Outlet Types in Grc_new_df:\n")
print(Grc_df['Outlet_Type'].value_counts())

# Lager en SupType_1 for 'Supermarket Type1'
SupType_1 = Grc_new_df[Grc_new_df['Outlet_Type'] == 'Supermarket Type1']

# Lager SupType_2 for 'Supermarket Type2'
SupType_2 = Grc_new_df[Grc_new_df['Outlet_Type'] == 'Supermarket Type2']

# verifiserer SupType_1
print(f"\nShape of SupType_1: {SupType_1.shape}")
print("First 5 rows of SupType_1:")
display(SupType_1.head())

# Verifiserer SupType_2
print(f"\nShape of SupType_2: {SupType_2.shape}")
print("First 5 rows of SupType_2:")
display(SupType_2.head())
# Out:
# Unique Outlet Types in Grc_new_df:
#
# Outlet_Type
# Supermarket Type1    3328
# Grocery Store         608
# Supermarket Type3     538
# Supermarket Type2     526
# Name: count, dtype: int64
#
# Shape of SupType_1: (3328, 10)
# First 5 rows of SupType_1:
#    Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 0         9.30          Low Fat         0.016047         Dairy  249.8092
# 2        17.50          Low Fat         0.016760          Meat  141.6180
# 4         8.93          Low Fat         0.000000     Household   53.8614
# 6        13.65          Regular         0.012741   Snack Foods   57.6588
# 8        16.20          Regular         0.016687  Frozen Foods   96.9726
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 2                       1999      Medium               Tier 1
# 4                       1987        High               Tier 3
# ...

# %% [markdown]
# Task 7:
#
# Using Seaborn (“ggplot style”) create a (2,1) subplot of a box plot showing 5-point summary of the column Item_MRP for SupType_1 and SupType_2.
# Which Outlet Type has a higher median MRP? Are there any outliers?

# %%
# Setter den visuelle stilen til 'ggplot' som spesifisert
plt.style.use('ggplot')

# Lager en figur og et setter med delplott et rutenett med 2 rader og 1 kolonne
# Figurstørrelsen er justert for bedre lesbarhet
fig, axes = plt.subplots(2, 1, figsize=(10, 8))

# Plot 1: Box plot for SupType_1
sns.boxplot(x=SupType_1['Item_MRP'], ax=axes[0])
axes[0].set_title('5-Point Summary of Item_MRP for Supermarket Type 1')
axes[0].set_xlabel('Item MRP') # Legger til en label for klargjøring

# Plot 2: Boc plot for SupType_2
sns.boxplot(x=SupType_2['Item_MRP'], ax=axes[1])
axes[1].set_title('5-Point Summary of Item_MRP for Supermarket Type 2')
axes[1].set_xlabel('Item MRP') # Legger igjen til en label

# Juster layouten for å forhindre at titler overlapper hverandre
plt.tight_layout()

# vis plottet
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Which Outlet Type has a higher median MRP?
#
# For å finne medianen ser vi på den vertikale streken inni boksen i hvert plott.
#
#     Ved å sammenligne de to plottene, kan vi se at median-streken for Supermarket Type 1 (det øverste plottet) er plassert litt lenger til høyre enn streken for Supermarket Type 2 (det nederste plottet). Forskjellen er veldig liten, men den er der.
#
# Svar: Supermarket Type 1 har en litt høyere median-MRP (pris) enn Supermarket Type 2.

# %%
print(f"Median MRP for Supermarket Type 1: {SupType_1['Item_MRP'].median()}")
print(f"Median MRP for Supermarket Type 2: {SupType_2['Item_MRP'].median()}")
# Out:
# Median MRP for Supermarket Type 1: 144.7457
# Median MRP for Supermarket Type 2: 130.18099999999998

# %% [markdown]
# Are there any outliers?
# Nei, det er ingen outliers for Item_MRP i noen av de to datasettene

# %% [markdown]
# Task 8:
#
# Concatenate the DataFrames SupType_1 and SupType_2 to create a new DataFrame Grc_Concat_df and sort it in ascending order based on the column Item_Outlet_Sales.
# What is the Outlet_Location_type of the store with the lowest sales?

# %%
# Concatenate the DataFrames SupType_1 and SupType_2 to create a 
# new DataFrame Grc_Concat_df and sort it in ascending order based on the column Item_Outlet_Sales.

# Slår sammen SupType_1 og SupType_2 til en ny DataFrame
# ignore_index=True nullstiller indeksen fra 0 til n-1 i den nye DataFrame-en
Grc_Concat_df = pd.concat([SupType_1, SupType_2], ignore_index=True)

print("The DataFrames are now merged.")
print(f"The new DataFrame Grc_Concat_df has {Grc_Concat_df.shape[0]} rows.")

# Sorterer DataFrame-en i stigende rekkefølge basert på 'Item_Outlet_Sales'
# inplace=True endrer DataFrame-en direkte uten å lage en ny kopi
Grc_Concat_df.sort_values(by='Item_Outlet_Sales', inplace=True)
print("Grc_Concat_df has been sorted by Item_Outlet_Sales.")
# Out:
# The DataFrames are now merged.
# The new DataFrame Grc_Concat_df has 3854 rows.
# Grc_Concat_df has been sorted by Item_Outlet_Sales.

# %%
# What is the Outlet_Location_type of the store with the lowest sales?

# Henter ut den første raden (som nå har det laveste salget)
row_with_lovest_sale = Grc_Concat_df.iloc[0]

# Henter ut verdien fra 'Outlet_Location_Type'-kolonnen i den raden

# Henter ut verdien fra 'Outlet_Location_Type'-kolonnen i den raden
location_type_lowest_sale = row_with_lovest_sale['Outlet_Location_Type']

# For å verifisere, ser vi på de 5 øverste radene i den sorterte DataFrame-en
print("\nTop 5 rows in the sorted DataFrame (shows lowest sales):")
display(Grc_Concat_df.head())

print(f"\nQuestion: What is the Outlet_Location_type of the store with the lowest sales?")
print(f"Answer: {location_type_lowest_sale}")
# Out:
# Top 5 rows in the sorted DataFrame (shows lowest sales):
#       Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 1582       20.500          Low Fat         0.143164     Household   34.9190
# 3494        6.635          Regular         0.046278  Frozen Foods   36.7506
# 3477        6.320          Low Fat         0.012770          Meat   39.9822
# 2396        9.105          Low Fat         0.038560     Household   33.8900
# 1825       19.250          Low Fat         0.108030     Household   32.4558
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1582                       1987        High               Tier 3
# 3494                       2009      Medium               Tier 3
# 3477                       2009      Medium               Tier 3
# 2396                       2002      Medium               Tier 2
# 1825                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# Task 9:
#
# Using columns Outlet_Size and Outlet_Location_Type to create a multiple index for Grc_Concat_df.

# %%
# Setter 'Outlet_Size' og 'Outlet_Location_Type' som den nye multipel indeksen
# Rekkefølgen i listen bestemmer hierarkiet: Outlet_Size er det ytre nivået,
# og Outlet_Location_Type er det indre nivået.
# inplace=True endrer DataFramen direkte.
Grc_Concat_df.set_index(['Outlet_Size', 'Outlet_Location_Type'], inplace=True)
print("Multiple index created successfully for Grc_Concat_df.")

# Display the first 10 rows to see the new multiple index
print("\nTop 10 rows of the DataFrame with the new multiple index:")
display(Grc_Concat_df.head(10))
# Out:
# Multiple index created successfully for Grc_Concat_df.
#
# Top 10 rows of the DataFrame with the new multiple index:
#                                   Item_Weight Item_Fat_Content  \
# Outlet_Size Outlet_Location_Type
# High        Tier 3                     20.500          Low Fat
# Medium      Tier 3                      6.635          Regular
#             Tier 3                      6.320          Low Fat
#             Tier 2                      9.105          Low Fat
# Small       Tier 1                     19.250          Low Fat
# Medium      Tier 1                      6.215          Low Fat
# Small       Tier 2                     20.700          Low Fat
# Medium      Tier 3                     15.100          Regular
#             Tier 3                     20.200          Low Fat
# High        Tier 3                      7.220          Regular
#
#                                   Item_Visibility              Item_Type  \
# Outlet_Size Outlet_Location_Type
# ...

# %% [markdown]
# Task 10:
#
# Cut the column Item_Weight of Grc_Concat_df into 10 buckets and compute each bucket's mean, minimum, maximum, and count.

# %%
# Trinn 1: Oppretter de 10 bøttene fra kolonnen 'Item_Weight'.
# pd.cut returnerer en serie med kategoriserte data som vi kan bruke til gruppering.
weight_buckets = pd.cut(Grc_Concat_df['Item_Weight'], bins=10)

# Trinn 2: Grupperer den opprinnelige DataFrame etter disse nye bøttene.
# Velger deretter kolonnen 'Item_Weight' fra disse gruppene og utfører aggregeringene.
bucket_analysis = Grc_Concat_df.groupby(weight_buckets, observed=True)['Item_Weight'].agg(['mean','min','max','count'])

# Vsier resultatet for verifisering
print("Analysis of Item_Weight Buckets:")
display(bucket_analysis)
# Out:
# Analysis of Item_Weight Buckets:
#                        mean     min     max  count
# Item_Weight
# (4.538, 6.234]     5.623814   4.555   6.215    253
# (6.234, 7.914]     7.121807   6.235   7.905    476
# (7.914, 9.594]     8.761867   7.930   9.500    450
# (9.594, 11.273]   10.344917   9.600  11.150    362
# (11.273, 12.952]  12.081635  11.300  12.850    419
# (12.952, 14.632]  13.716193  13.000  14.600    352
# (14.632, 16.312]  15.495976  14.650  16.250    410
# (16.312, 17.991]  17.172672  16.350  17.850    408
# (17.991, 19.671]  18.838005  18.000  19.600    396
# (19.671, 21.35]   20.357012  19.700  21.350    328
